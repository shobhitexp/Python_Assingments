# %% [markdown]
# ![Screenshot 2023-07-19 at 11.35.21 PM.png](data:image/png;base64,...)

# %% [markdown]
# ---------
# Answer 1 :-

# %%
import math

def check(n) :

    count_digits = len(str(n))

    sum = 0
    x = n
    while (x!=0) :

        r = x % 10

        sum = (int) (sum + math.pow(r, count_digits))
        count_digits = count_digits - 1
        x = x//10

    if sum == n :
        return 1
    else :
        return 0

n = int(input("Enter your number for checking Disarium Number :- "))
if (check(n) == 1) :
    print ("Your given a Disarium Number")
else :
    print ("Not a Disarium Number")
# Out:
# Enter your number for checking Disarium Number :- 135
# Your given a Disarium Number

# %% [markdown]
# -----------
# Answer 2 :-

# %%
import math

def check(i) :

    count_digits = len(str(i))

    sum = 0
    x = i
    while (x!=0) :

        r = x % 10

        sum = (int) (sum + math.pow(r, count_digits))
        count_digits = count_digits - 1
        x = x//10

    if sum == i :
        return 1
    else :
        return 0

for i in range(1,101):
  if (check(i) == 1) :
    print (i)
  else:
    pass
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 89

# %% [markdown]
# --------
# Answer 3 :-

# %%
def isHappyNumber(num):
    rem = sum = 0

    while(num > 0):
        rem = num%10
        sum = sum + (rem*rem)
        num = num//10
    return sum

num = int(input("Enter your number :- "))
result = num

while(result != 1 and result != 4):
    result = isHappyNumber(result)

if(result == 1):
    print(str(num) + " is a happy number")

elif(result == 4):
    print(str(num) + " is not a happy number")
# Out:
# Enter your number :- 82
# 82 is a happy number

# %% [markdown]
# -----------
# Answer 4 :-

# %%
def isHappyNumber(num):
    rem = sum = 0

    while(num > 0):
        rem = num%10
        sum = sum + (rem*rem)
        num = num//10
    return sum

print("List of happy numbers between 1 and 100 :- ")
for i in range(1, 101):
    result = i

    while(result != 1 and result != 4):
        result = isHappyNumber(result)

    if(result == 1):
        print(i)
# Out:
# List of happy numbers between 1 and 100 :-
# 1
# 7
# 10
# 13
# 19
# 23
# 28
# 31
# 32
# 44
# 49
# 68
# 70
# 79
# 82
# 86
# 91
# 94
# 97
# 100

# %% [markdown]
# ---------
# Answer 5 :-

# %%
num = int(input("Enter yor number :- "))
rem = sum = 0

#Make a copy of num and store it in variable n
n = num
#Calculates sum of digits
while(num > 0):
    rem = num%10
    sum = sum + rem
    num = num//10
#Checks whether the number is divisible by the sum of digits
if(n%sum == 0):
    print(str(n) + " is a harshad number")
else:
    print(str(n) + " is not a harshad number")
# Out:
# Enter yor number :- 156
# 156 is a harshad number

# %% [markdown]
# -----------
# Answer 6 :-

# %%
def isPronicNumber(num):
    flag = False;
    for j in range(1, num+1):
        if((j*(j+1)) == num):
            flag = True
            break
    return flag
print("Pronic numbers between 1 To 100 :- ")
for i in range(1, 101):
    if(isPronicNumber(i)):
        print(i)
# Out:
# Pronic numbers between 1 To 100 :-
# 2
# 6
# 12
# 20
# 30
# 42
# 56
# 72
# 90

# %% [markdown]
# -----------
# -----------
