# %% [markdown]
# ![Screenshot 2023-07-18 at 3.21.12 PM.png](data:image/png;base64,...)

# %% [markdown]
# -----------
# Answer 1 :-

# %%
def fibonacci(no):
    if no <= 0:
        return []
    elif no == 1:
        return [0]
    elif no == 2:
        return [0, 1]
    else:
        sequence = fibonacci(no - 1)
        sequence.append(sequence[-1] + sequence[-2])
        return sequence
num = int(input("Enter the number of Fibonacci terms to generate :- "))
result = fibonacci(num)
print("The Fibonacci sequence :- ")
for num in result:
    print(num, end=" ")

# %% [markdown]
# -----------
# Answer 2 :-

# %%
def fact(num):
    if num == 0:
      return 1
    else:
      return num * fact(num-1)
num=int(input("Enter number to find factorial :- "))
result = fact(num)
print(result)

# %% [markdown]
# ---------
# Answer 3 :-

# %%
def calc_bmi(weight,height):
    bmi=weight/(height**2)
    return bmi
weight = float(input("Enter your weight in kilograms :- "))
height = float(input("Enter your height in meters :- "))
bmi = calc_bmi(weight, height)
print("Your BMI is:", bmi)
# Out:
# Enter your weight in kilograms: 74
# Enter your height in meters: 1.78
# Your BMI is: 23.355636914530994

# %% [markdown]
# ------------------
# Answer 4 :-

# %%
import math
num = float(input("Enter a number: "))
ln = math.log(num)
print("The natural logarithm of", num, "is", ln)
# Out:
# Enter a number: 1
# The natural logarithm of 1.0 is 0.0

# %% [markdown]
# --------
# Answer 5 :-

# %%
def cube(n):
    sum=0
    for i in range(1,n+1):
        sum+=i**3
    return sum
n=int(input("Enter the value of 'n' :- "))
result=cube(n)
print("Cube sum of the first", n, "natural numbers is :- ", result)
# Out:
# Enter the value of 'n' :- 78
# Cube sum of the first 78 natural numbers is :-  9492561

# %% [markdown]
# ------------
# ------------
