# %% [markdown]
# ![Screenshot 2023-07-17 at 9.29.57 AM.png](data:image/png;base64,...)

# %% [markdown]
# --------
# 1 Answer :-

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# -----------
#
# 2 Answer :-

# %%
a,b,c,d=3,4,5,6
print(a+c)#. Arthmetic
print(d/b)#. Division
print(d//b)#. int division
# Out:
# 8
# 1.5
# 1

# %% [markdown]
# -------
#
# 3 Answer :-

# %%
def trangle(breath,height):
  return ((1/2*breath)*height)
breath=float(input("Enter Base of your trangle : - "))
height=float(input("Enter Height of your trangle : - "))
trangle(breath,height)
# Out:
# Enter Base of your trangle : - 8
# Enter Height of your trangle : - 12
# 48.0

# %% [markdown]
# -------
#
# 4 Answer :-

# %%
val1=234
val2=23456
print("Before Swapping ")
print(val1)
print(val2)
val1,val2=val2,val1
print("After Swapping ")
print(val1)
print(val2)
# Out:
# Before Swapping
# 234
# 23456
# After Swapping
# 23456
# 234

# %% [markdown]
# -------
# 5 Answer :-

# %%
import random
print(random.randint(0,100))
# Out:
# 34

# %% [markdown]
# ------
