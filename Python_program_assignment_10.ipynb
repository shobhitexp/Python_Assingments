# %% [markdown]
# ![Screenshot 2023-07-20 at 8.51.22 PM.png](data:image/png;base64,...)

# %% [markdown]
# ---------
# Answer 1 : -

# %%
ls=list(map(int,input("\nEnter the numbers :- ").strip().split()))
count=0
for i in range(0,len(ls)):
  count=count+(ls[i])
print("sum of given list :- ",count)
# Out:
# Enter the numbers :- 1 2 3 4 5
# sum of given list :-  15

# %% [markdown]
# ------------
# Answer 2 : -

# %%
ls=list(map(int,input("\nEnter the numbers : ").strip().split()))
count=1
for i in range(0,len(ls)):
  count*=(ls[i])
print("Multiplication of given list :- ",count)
# Out:
# Enter the numbers : 1 2 3 4 5
# Multiplication of given list :-  120

# %% [markdown]
# -----------
# Answer 3 : -

# %%
lst=list(map(int,input("\nEnter the numbers :- ").strip().split()))
min=lst[0]
for i in range(len(lst)):
  if lst[i] < min:
    min = lst[i]
print("The smallest element in the list is :- ",min)
# Out:
# Enter the numbers :- 2 3 4 5 1 0 6 8 8 9
# The smallest element in the list is :-  0

# %% [markdown]
# --------------
# Answer 4 : -

# %%
lst=list(map(int,input("\nEnter the numbers :- ").strip().split()))
min=lst[0]
for i in range(len(lst)):
  if lst[i] > min:
    min = lst[i]
print("The largest element in the list is :- ",min)
# Out:
# Enter the numbers :- 2 3 4 5 1 0 6 8 82 9
# The largest element in the list is :-  82

# %% [markdown]
# ---------
# Answer 5 : -

# %%
list1=list(map(int,input("\nEnter the numbers :- ").strip().split()))
print("Second largest element is:", sorted(list1)[-2])
# Out:
# Enter the numbers :- 2 3 4 5 1 0 6 8 8 9
# Second largest element is: 8

# %% [markdown]
# ----------
# Answer 6 : -

# %%
lst=list(map(int,input("\nEnter the numbers :- ").strip().split()))
min=lst[0]
for i in range(len(lst)):
  if lst[i] > min:
    min = i+1
print("The N largest element in the list is :- ",min,"th")
# Out:
# Enter the numbers :- 2 3 4 5 1 0 6 8 82 9
# The N largest element in the list is :-  9 th

# %% [markdown]
# -----------
# Answer 7 : -

# %%
lst=list(map(int,input("\nEnter the numbers :- ").strip().split()))
for i in range(0,len(lst)):
  if lst[i] % 2 == 0:
    print(lst[i])
# Out:
# Enter the numbers :- 2 3 4 5 1 0 6 8 82 9
# 2
# 4
# 0
# 6
# 8
# 82

# %% [markdown]
# -----------
# Answer 8 : -

# %%
lst=list(map(int,input("\nEnter the numbers :- ").strip().split()))
for i in range(0,len(lst)):
  if lst[i] % 2 != 0:
    print(lst[i])
# Out:
# Enter the numbers :- 2 3 4 5 1 0 6 8 82 9 7 15 13 11
# 3
# 5
# 1
# 9
# 7
# 15
# 13
# 11

# %% [markdown]
# -------------
# Answer 9 : -

# %%
lst=[5, 6, [], 3, [], [],[] ,45,2,2,[],22,9]
res = list(filter(None, lst))
print("List after empty list removal : " + str(res))
# Out:
# List after empty list removal : [5, 6, 3, 45, 2, 2, 22, 9]

# %% [markdown]
# ---------
# Answer 10 : -

# %%
def Cloning(lis):
    liscopy = lis[:]
    return liscopy
lis = [4, 8, 2, 10, 15, 18]
final = Cloning(lis)
print("Original List:", lis)
print("After Cloning:", final)
# Out:
# Original List: [4, 8, 2, 10, 15, 18]
# After Cloning: [4, 8, 2, 10, 15, 18]

# %% [markdown]
# ----------
# Answer 11 : -

# %%
def countX(lst, x):
    count = 0
    for ele in lst:
        if (ele == x):
            count = count + 1
    return count
lst = [8, 6, 8, 10, 8, 20, 10, 8, 8]
x = 8
print('{} has occurred {} times'.format(x,countX(lst, x)))
# Out:
# 8 has occurred 5 times

# %% [markdown]
# -----------
# -----------
