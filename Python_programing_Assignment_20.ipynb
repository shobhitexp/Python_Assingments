# %% [markdown]
# Question1
# Create a function that takes a list of strings and integers, and filters out the list so that it
# returns a list of integers only.
# ######Examples
# ######filter_list([1, 2, 3, &quot;a&quot;, &quot;b&quot;, 4]) ➞ [1, 2, 3, 4]
# ######filter_list([&quot;A&quot;, 0, &quot;Edabit&quot;, 1729, &quot;Python&######quot;, &quot;1729&quot;]) ➞ [0, 1729]
# ######filter_list([&quot;Nothing&quot;, &quot;here&quot;]) ➞ []

# %%
def filter(list_of_elements):
  integers = []
  for element in list_of_elements:
    if isinstance(element,int):
      integers.append(element)
  return integers
list_of_elements=[1, 2, 3, "a", "b", 4]
filter(list_of_elements)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# --------------
# Question2
# Given a list of numbers, create a function which returns the list but with each element&#39;s
# index in the list added to itself. This means you add 0 to the number at index 0, add 1 to the
# number at index 1, etc...
# ######Examples
# ######add_indexes([0, 0, 0, 0, 0]) ➞ [0, 1, 2, 3, 4]
# ######add_indexes([1, 2, 3, 4, 5]) ➞ [1, 3, 5, 7, 9]
# ######add_indexes([5, 4, 3, 2, 1]) ➞ [5, 5, 5, 5, 5]

# %%
def ls(lis):
  new=[]
  for i in range(0,len(lis)):
    new.append(lis[i]+i)
  return new
lis=list(map(int,input("\nEnter the numbers :- ").strip().split(",")))
ls(lis)
# Out:
# Enter the numbers :- 0,0,0,0,0
# [0, 1, 2, 3, 4]

# %% [markdown]
# ------------
# Question3
# Create a function that takes the height and radius of a cone as arguments and returns the
# volume of the cone rounded to the nearest hundredth. See the resources tab for the formula.
#
# ######Examples
# ######cone_volume(3, 2) ➞ 12.57
# ![Screenshot 2023-08-03 at 12.25.04 AM.png](data:image/png;base64,...)
#
# ######cone_volume(15, 6) ➞ 565.49
# cone_volume(18, 0) ➞ 0

# %%
import math
def volume(height,radius):
  vol=(math.pi*radius**2*height)/3
  return round(vol,2) # The first argument is the number that needs to be rounded. and 2 for The second argument is the number of decimal places to which the first argument should be rounded.

height,radius=map(int,input("\nEnter the numbers :- ").strip().split(","))
volume(height,radius)
# Out:
# Enter the numbers :- 15,6
# 565.4866776461628

# %% [markdown]
# ------------
# Question4
# This Triangular Number Sequence is generated from a pattern of dots that form a triangle.
# The first 5 numbers of the sequence, or dots, are:
# 1, 3, 6, 10, 15
# This means that the first triangle has just one dot, the second one has three dots, the third one
# has 6 dots and so on.
# Write a function that gives the number of dots with its corresponding triangle number of the
# sequence.

# %%
def dot(num):
  val=(num**2+num)/2
  return int(val) # 1 3 6 10 15
                  #  2 3 4  5
                  #   1 2  3 the here we see if we go for sum of n natural no then directely fallowerd by above series n(n+1)/2
num=int(input("Enter Number :- "))
dot(num)
# Out:
# Enter Number :- 215
# 23220

# %% [markdown]
# ------------
# Question5
# Create a function that takes a list of numbers between 1 and 10 (excluding one number) and
# returns the missing number.
# ######Examples
# ######missing_num([1, 2, 3, 4, 6, 7, 8, 9, 10]) ➞ 5
# ######missing_num([7, 2, 3, 6, 5, 9, 1, 4, 8]) ➞ 10
# ######missing_num([10, 5, 1, 2, 4, 6, 8, 3, 9]) ➞ 7

# %%
def missing(num):
  num.sort()
  for i in range(0,len(num)):
    if num[i+1]-num[i]!=1:
      return i+2

num=list(map(int,input("\nEnter the numbers :- ").strip().split(",")))
missing(num)
# Out:
# Enter the numbers :- 10, 5, 1, 2, 4, 6, 8, 3, 9
# 7

# %% [markdown]
# -------------
# -------------
